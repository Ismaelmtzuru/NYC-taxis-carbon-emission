# %%
from pycaret.classification import *
from pycaret.regression import *
from pycaret.regression import *
import pandas as pd

# %%
data = pd.read_csv('clima\\clima.csv')

# %%
# Se elimina los datos faltantes o nulos para que no exista alguna interferencia con Pycaret
data.drop(data[data['temperature_2m_mean'].isnull()].index,inplace=True)

# %%
data
# Out:
#       Unnamed: 0                 date  temperature_2m_max  temperature_2m_min  \
# 0              0  2015-01-01 05:00:00            2.361000             -4.2890
# 1              1  2015-01-02 05:00:00            5.261000             -2.0890
# 2              2  2015-01-03 05:00:00            8.011001             -2.7390
# 3              3  2015-01-04 05:00:00           13.661000              7.6110
# 4              4  2015-01-05 05:00:00            6.061000             -4.3390
# ...          ...                  ...                 ...                 ...
# 3283        3283  2023-12-28 05:00:00           11.417500              9.0175
# 3284        3284  2023-12-29 05:00:00           13.167500              7.4175
# 3285        3285  2023-12-30 05:00:00            7.717500              1.2175
# 3286        3286  2023-12-31 05:00:00            6.267500             -1.8825
# 3287        3287  2024-01-01 05:00:00            7.317500             -0.5325
#
#       temperature_2m_mean  snowfall_sum  precipitation_hours
# 0               -1.245250          0.00                  0.0
# 1                0.950583          0.00                  0.0
# 2                1.721417          3.08                 11.0
# 3               10.054749          0.00                 12.0
# 4                0.867250          0.00                  0.0
# ...                   ...           ...                  ...
# 3283            10.019583          0.00                 21.0
# 3284             9.432082          0.00                  3.0
# 3285             5.046667          0.00                  2.0
# 3286             2.782084          0.07                  1.0
# 3287             3.284167          0.00                  0.0
#
# [3288 rows x 7 columns]

# %%
# Se configura en 'target' la columna 'temperature_2m_max' porque deseamos predecir la temperatura máxima
s = setup(data, target = 'temperature_2m_max', session_id = 123)
# Out:
# <style type="text/css">
# #T_9d43c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9d43c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d43c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9d43c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d43c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d43c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9d43c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d43c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9d43c_row1_col1" class="data row1 col1" >temperature_2m_max</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d43c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9d43c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d43c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9d43c_row3_col1" class="data row3 col1" >(3288, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d43c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9d43c_row4_col1" class="data row4 col1" >(3288, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9d43c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9d43c_row5_col1" class="data row5 col1" >(2301, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9d43c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9d43c_row6_col1" class="data row6 col1" >(987, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9d43c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9d43c_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9d43c_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_9d43c_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9d43c_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_9d43c_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9d43c_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_9d43c_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9d43c_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_9d43c_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9d43c_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_9d43c_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9d43c_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_9d43c_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9d43c_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_9d43c_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9d43c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_9d43c_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9d43c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_9d43c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9d43c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_9d43c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9d43c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_9d43c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9d43c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_9d43c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9d43c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_9d43c_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9d43c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9d43c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_9d43c_row21_col1" class="data row21 col1" >3451</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# En [Target type -->	Regression] nos indica que el tipo de modelo será de regresión linear.

# %%
# Lo usamos para comparar todos los tipos de regresión que existe
best = compare_models()
# Out:
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %%
# Indica que el mejor regresos es 'HuberRegressor'
print(best)
# Out:
# HuberRegressor(alpha=0.0001, epsilon=1.35, fit_intercept=True, max_iter=100,
#                tol=1e-05, warm_start=False)

# %%
# se evalua el modelo.
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
'''Aqui nos muestra que el modelo es altamente confiable. En las dos últimas colúmnas se puede ver la columna
que se desea predecir y en 'prediction_label' se muestra la predicción'''
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8bdfa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bdfa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8bdfa_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8bdfa_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8bdfa_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8bdfa_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8bdfa_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8bdfa_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bdfa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8bdfa_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_8bdfa_row0_col1" class="data row0 col1" >0.7909</td>
#       <td id="T_8bdfa_row0_col2" class="data row0 col2" >1.1002</td>
#       <td id="T_8bdfa_row0_col3" class="data row0 col3" >1.0489</td>
#       <td id="T_8bdfa_row0_col4" class="data row0 col4" >0.9884</td>
#       <td id="T_8bdfa_row0_col5" class="data row0 col5" >0.1296</td>
#       <td id="T_8bdfa_row0_col6" class="data row0 col6" >0.1855</td>
#     </tr>
#   </tbody>
# </table>
#       Unnamed: 0                 date  temperature_2m_min  \
# 1173        1173  2018-03-19 05:00:00           -2.232500
# 2411        2411  2021-08-08 05:00:00           19.417501
# 2266        2266  2021-03-16 05:00:00           -4.082500
# 1432        1432  2018-12-03 05:00:00            6.017500
# 712          712  2016-12-13 05:00:00           -1.689000
# ...          ...                  ...                 ...
# 5              5  2015-01-06 05:00:00           -6.639000
# 1155        1155  2018-03-01 05:00:00            4.017500
# 1578        1578  2019-04-28 05:00:00            5.867500
# 116          116  2015-04-27 05:00:00            5.161000
# 12            12  2015-01-13 05:00:00           -7.939000
#
#       temperature_2m_mean  snowfall_sum  precipitation_hours  \
# 1173             1.790417          0.00                  0.0
# 2411            20.996668          0.00                 22.0
# 2266            -0.380417          0.07                  1.0
# 1432            10.177917          0.00                  0.0
# 712              1.550583          0.00                  0.0
# ...                   ...           ...                  ...
# 5               -5.626500          1.05                  6.0
# 1155             9.646667          0.00                  5.0
# 1578             8.692500          0.00                  5.0
# 116             10.154752          0.00                  0.0
# 12              -3.722334          0.21                  2.0
#
#       temperature_2m_max  prediction_label
# 1173            7.267500          6.185383
# 2411           22.467501         22.648196
# 2266            2.667500          3.783845
# 1432           12.817500         14.716184
# 712             4.811000          5.396777
# ...                  ...               ...
# 5              -4.589000         -3.671924
# 1155           15.517500         14.872440
# 1578           11.067500         12.049867
# 116            14.861000         15.191430
# 12              1.011000          0.611894
#
# [987 rows x 8 columns]

# %%
predictions = predict_model(best)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8c8ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c8ab_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8c8ab_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8c8ab_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8c8ab_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8c8ab_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8c8ab_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8c8ab_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c8ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c8ab_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_8c8ab_row0_col1" class="data row0 col1" >0.7909</td>
#       <td id="T_8c8ab_row0_col2" class="data row0 col2" >1.1002</td>
#       <td id="T_8c8ab_row0_col3" class="data row0 col3" >1.0489</td>
#       <td id="T_8c8ab_row0_col4" class="data row0 col4" >0.9884</td>
#       <td id="T_8c8ab_row0_col5" class="data row0 col5" >0.1296</td>
#       <td id="T_8c8ab_row0_col6" class="data row0 col6" >0.1855</td>
#     </tr>
#   </tbody>
# </table>
#       Unnamed: 0                 date  temperature_2m_min  \
# 1173        1173  2018-03-19 05:00:00           -2.232500
# 2411        2411  2021-08-08 05:00:00           19.417501
# 2266        2266  2021-03-16 05:00:00           -4.082500
# 1432        1432  2018-12-03 05:00:00            6.017500
# 712          712  2016-12-13 05:00:00           -1.689000
#
#       temperature_2m_mean  snowfall_sum  precipitation_hours  \
# 1173             1.790417          0.00                  0.0
# 2411            20.996668          0.00                 22.0
# 2266            -0.380417          0.07                  1.0
# 1432            10.177917          0.00                  0.0
# 712              1.550583          0.00                  0.0
#
#       temperature_2m_max  prediction_label
# 1173            7.267500          6.185383
# 2411           22.467501         22.648196
# 2266            2.667500          3.783845
# 1432           12.817500         14.716184
# 712             4.811000          5.396777

# %%
# Aquí se guarda el modelo para un uso posterior.
save_model(best,'prediccion_temp_max')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\ISMAEL\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Unnamed: 0', 'temperature_2m_min',
#                                               'temperature_2m_mean',
#                                               'snowfall_sum',
#                                               'precipitation_hours'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_val...
#                                                                handle_unknown='value',
#                                                                hierarchy=None,
#                                                                min_samples_leaf=20,
#                                                                return_df=True,
#                                                                smoothing=10,
#                                                                verbose=0))),
#                  ('clean_column_names',
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                  ('trained_model',
#                   HuberRegressor(alpha=0.0001, epsilon=1.35, fit_intercept=True,
#                                  max_iter=100, tol=1e-05, warm_start=False))],
#           verbose=False),
#  'prediccion_temp_max.pkl')
